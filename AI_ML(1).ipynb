# %% [markdown]
# <a href="https://colab.research.google.com/github/Rasika-Mate/Goggle-AI-ML-Virtual-Internship/blob/main/AI_ML(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
speed = 3  # Assigning a value to speed
if speed < 4:
    status = "WALKING"

# %%
if speed < 4:
    status = "WALKING"
else:
    status= "RUNNING"

# %%
if speed < 4:
    status = "WALKING"
elif speed < 12:
    status = "RUNNING"
else:
    status = "BIKING"

# %%
# Create first Model
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# Define and compile the neural network
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
# Loss and optimizer functions for different scenarios.
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Provide the data
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
# Train the Neural Network
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 304ms/step - loss: 46.8677
# Epoch 2/500
# 1/1 [==============================] - 0s 11ms/step - loss: 36.8747
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 29.0127
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 22.8272
# Epoch 5/500
# 1/1 [==============================] - 0s 5ms/step - loss: 17.9607
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 14.1320
# Epoch 7/500
# 1/1 [==============================] - 0s 5ms/step - loss: 11.1197
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.7498
# Epoch 9/500
# 1/1 [==============================] - 0s 11ms/step - loss: 6.8852
# Epoch 10/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.4182
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.2640
# Epoch 12/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.3559
# ...

# %%
# Use the model
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 64ms/step
# [[31.001444]]
